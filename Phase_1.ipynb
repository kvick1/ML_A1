# %% [markdown]
# # Predicting Employment of Students at an University Campus

# %% [markdown]
# ## Phase 1: Data Pre-processing, Exploration, and Visualisation

# %% [markdown]
# ### Group 46
# ### Zhaojin Liu s3206722, Martin Thu s3494324, Klara Vickov s3873315

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# ## Introduction

# %%
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# Import necessary libraries

# %%
import pandas as pd 
import requests
import numpy as np
import io

# %% [markdown]
# ### Dataset Source
# *The dataset was sourced from Kaggle.*

# %% [markdown]
# ### Dataset Details
# *Describe in detail what the dataset is about*
#
# *Report number of observations (rows) and features (columns)*
#
# *Print 10 random observations*

# %% [markdown]
# This code is to be displayed before running any pandas data frames:

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# Read in data set from GitHub repository

# %%
df_url = 'https://raw.githubusercontent.com/kvick1/ML_A1/main/Placement_Data_Full_Class.csv'
url_content = requests.get(df_url, verify=False).content
placement = pd.read_csv(io.StringIO(url_content.decode('utf-8')))

# %%
placement.shape
# Out:
# (215, 15)

# %%
placement.sample(n=10, random_state=999)
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 148    149      F  77.00  Central  86.00  Central      Arts     56.00
# 191    192      M  67.00   Others  61.00  Central   Science     72.00
# 125    126      F  84.00  Central  73.00  Central  Commerce     73.00
# 68      69      F  69.70  Central  47.00  Central  Commerce     72.70
# 187    188      M  78.50  Central  65.50  Central   Science     67.00
# 91      92      M  52.00  Central  57.00  Central  Commerce     50.80
# 174    175      M  73.24   Others  50.83   Others   Science     64.27
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# 122    123      F  66.50  Central  66.80  Central      Arts     69.30
# 47      48      M  63.00  Central  60.00  Central  Commerce     57.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 148     Others     No     57.0        Mkt&Fin  64.08      Placed  240000.0
# 191  Comm&Mgmt     No     72.0        Mkt&Fin  61.01      Placed  264000.0
# 125  Comm&Mgmt     No     75.0        Mkt&Fin  73.33      Placed  350000.0
# 68    Sci&Tech     No     79.0         Mkt&HR  59.24  Not Placed       NaN
# 187   Sci&Tech    Yes     95.0        Mkt&Fin  64.86      Placed  280000.0
# 91   Comm&Mgmt     No     67.0         Mkt&HR  62.79  Not Placed       NaN
# 174   Sci&Tech    Yes     64.0        Mkt&Fin  66.23      Placed  500000.0
# 7     Sci&Tech    Yes     67.0        Mkt&Fin  62.14      Placed  252000.0
# 122  Comm&Mgmt    Yes     80.4        Mkt&Fin  71.00      Placed  236000.0
# 47   Comm&Mgmt    Yes     78.0        Mkt&Fin  54.55      Placed  204000.0

# %% [markdown]
# ### Dataset Features
# *Explain features that will be included in project in a table format*
#
# *Table needs one feature per row with 4 columns - feature name, data type, units, brief description*
#
# *Target Feature*

# %% [markdown]
# The salary feature will not be included in our project because it is only included for students who have received a placement. As our model will only be looking at whether students receive a placement, the salary amount is irrelevant.

# %%
placement.columns.values
# Out:
# array(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation',
#        'mba_p', 'status', 'salary'], dtype=object)

# %%
placement.dtypes
# Out:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# salary            float64
# dtype: object

# %%
placement = placement.drop(columns=['salary'])

# %%
placement.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed

# %% [markdown]
# ## Goals and Objectives
# *Goals and objectives for modeling*

# %% [markdown]
# ## Data Cleaning and Preprocessing
# *deal with missing values, outliers, incorrect values*
#
# *drop ID-like columns*
#
# *add subsections for each cleaning process*

# %% [markdown]
# Checking for missing values. No missing values

# %%
placement.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# dtype: int64

# %%
placement.describe(include=np.number).round(3)
# Out:
#          sl_no    ssc_p    hsc_p  degree_p  etest_p    mba_p
# count  215.000  215.000  215.000   215.000  215.000  215.000
# mean   108.000   67.303   66.333    66.370   72.101   62.278
# std     62.209   10.827   10.898     7.359   13.276    5.833
# min      1.000   40.890   37.000    50.000   50.000   51.210
# 25%     54.500   60.600   60.900    61.000   60.000   57.945
# 50%    108.000   67.000   65.000    66.000   71.000   62.000
# 75%    161.500   75.700   73.000    72.000   83.500   66.255
# max    215.000   89.400   97.700    91.000   98.000   77.890

# %% [markdown]
# Drop ID-like column

# %%
placement.rename(columns = {'sl_no': 'ID'},inplace = True)
placement
# Out:
#       ID gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..   ...    ...    ...      ...    ...      ...       ...       ...
# 210  211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211  212      M  58.00   Others  60.00   Others   Science     72.00
# 212  213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213  214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214  215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed
# 3     Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed
# ..         ...    ...      ...            ...    ...         ...
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed
#
# [215 rows x 14 columns]

# %%
placement.set_index('ID', inplace = True)
placement
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# ID
# 1        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 2        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 3        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 4        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 5        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 211      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 212      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 213      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 214      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 215      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status
# ID
# 1       No     55.0         Mkt&HR  58.80      Placed
# 2      Yes     86.5        Mkt&Fin  66.28      Placed
# 3       No     75.0        Mkt&Fin  57.80      Placed
# 4       No     66.0         Mkt&HR  59.43  Not Placed
# 5       No     96.8        Mkt&Fin  55.50      Placed
# ..     ...      ...            ...    ...         ...
# 211     No     91.0        Mkt&Fin  74.49      Placed
# 212     No     74.0        Mkt&Fin  53.62      Placed
# 213    Yes     59.0        Mkt&Fin  69.72      Placed
# 214     No     70.0         Mkt&HR  60.23      Placed
# 215     No     89.0         Mkt&HR  60.22  Not Placed
#
# [215 rows x 13 columns]

# %% [markdown]
# ## Data Exploration and Visualisation
# *charts and graphs as appropriate with proper labels and explanation*
#
# *4 plots each of : 1-variable, 2-variable, 3-variable (12 in total)*

# %% [markdown]
# ## Literature Review
# *Advanced submission - 600+ words*
#
# *minimum 10 journal articles and 4 conference papers in a dedicated references section*

# %% [markdown]
# ## Summary and Conclusions
# *Summarise phase 1 state insights gained*

# %% [markdown]
# ## References
# *References from advanced submission and report in general*

# %% [markdown]
# All pandas data frames to be rounded to 3 decimal places

# %%
df = df.style.set_precision(3)

# %% [markdown]
# Do not display more than 10 lines of a pandas data frame
